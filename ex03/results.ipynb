# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
files = ['part-00000', 'part-00001', 'part-00002']

list_df = []
for file in files:
    _df = pd.read_table(file, index_col=None, header=None)
    list_df.append(_df)
df = pd.concat(list_df, axis=0, ignore_index=True)
df.columns = ['temp', 'count']

df = df.sort_values('temp')
print(df.shape)
df
# Out:
# (64, 2)
#     temp   count
# 48   -25       5
# 25   -24      18
# 5    -23      15
# 47   -22      15
# 24   -21      21
# 4    -20      32
# 46   -19      69
# 23   -18     104
# 2    -17     131
# 45   -16     168
# 22   -15     261
# 1    -14     383
# 44   -13     590
# 21   -12     934
# 0    -11    1400
# 43   -10    2185
# 28    -9    3259
# 7     -8    4694
# 50    -7    7085
# 27    -6   10726
# 6     -5   16968
# 49    -4   25436
# 26    -3   36568
# 3     -2   51963
# 42    -1   66365
# 29     0  114487
# 51     1  100972
# 11     2  104104
# 36     3  107513
# 62     4  111125
# ..   ...     ...
# 41     9  112717
# 52    10  113493
# 8     11  112503
# 30    12  113919
# 53    13  114613
# 9     14  113347
# 31    15  112708
# 54    16  108710
# 10    17  102114
# 32    18   92404
# 55    19   81381
# 12    20   72875
# 33    21   63991
# 56    22   56530
# 13    23   48804
# 34    24   41558
# 57    25   35032
# 14    26   28762
# 35    27   22974
# 58    28   17409
# ...

# %%
plt.figure(figsize=(12,8))

plt.hist(df['temp'], weights=df['count'], bins=64, facecolor='r')

plt.xticks(range(-25, 40+1, 4))
plt.grid(True, which='both', axis='both')

plt.title('Histogram of temperature in Switzerland')
plt.xlabel('Temperature [°C]')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# How often does the temperature 22 degrees celsius occur?'

# %%
df.loc[df['temp'] == 22]
# Out:
#     temp  count
# 56    22  56530

# %% [markdown]
# What is the lowest and highest temperature occuring?

# %%
df.min()['temp']
# Out:
# -25

# %%
df.max()['temp']
# Out:
# 38

# %% [markdown]
# Which temperature occurs most often?

# %%
df.loc[df['count'] == df.max()['count']]
# Out:
#     temp   count
# 53    13  114613
